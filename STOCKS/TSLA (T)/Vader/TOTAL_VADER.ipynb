# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv('/content/drive/MyDrive/JU PROJ/EXEC_Tesla_stock_data_Vader.csv', index_col = False)
df1
# Out:
#             Date       Close  negative   neutral  positive        Open  \
# 0     2017-01-03   43.397999  0.050500  0.886250  0.063125   42.972000
# 1     2017-01-04   45.397999  0.074762  0.850238  0.075048   42.950001
# 2     2017-01-05   45.349998  0.000000  0.785000  0.215000   45.284000
# 3     2017-01-06   45.801998       NaN       NaN       NaN   45.386002
# 4     2017-01-09   46.256001       NaN       NaN       NaN   45.793999
# ...          ...         ...       ...       ...       ...         ...
# 1341  2022-05-02  902.940002       NaN       NaN       NaN  860.770020
# 1342  2022-05-03  909.250000       NaN       NaN       NaN  903.179993
# 1343  2022-05-04  952.619995       NaN       NaN       NaN  903.940002
# 1344  2022-05-05  873.280029  0.035167  0.883167  0.081667  939.020020
# 1345  2022-05-06  865.650024       NaN       NaN       NaN  887.000000
#
#             High         Low    Volume
# 0      44.066002   42.192001  29616500
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/JU PROJ/GENERAL_Tesla_stock_data_Vader.csv', index_col = False)
df2
# Out:
#             Date       Close  negative   neutral  positive        Open  \
# 0     2017-01-03   43.397999  0.181000  0.763500  0.055500   42.972000
# 1     2017-01-04   45.397999  0.009286  0.897286  0.093429   42.950001
# 2     2017-01-05   45.349998  0.000000  0.898000  0.102000   45.284000
# 3     2017-01-06   45.801998  0.072000  0.928000  0.000000   45.386002
# 4     2017-01-09   46.256001  0.000000  0.815000  0.185000   45.793999
# ...          ...         ...       ...       ...       ...         ...
# 1341  2022-05-02  902.940002  0.045250  0.844950  0.109800  860.770020
# 1342  2022-05-03  909.250000  0.024722  0.908667  0.066611  903.179993
# 1343  2022-05-04  952.619995  0.044100  0.871200  0.084650  903.940002
# 1344  2022-05-05  873.280029  0.040071  0.894964  0.064929  939.020020
# 1345  2022-05-06  865.650024  0.017500  0.930214  0.052286  887.000000
#
#             High         Low    Volume
# 0      44.066002   42.192001  29616500
# ...

# %%
# Set date as Index
df1 = df1.set_index('Date')
df1 = df1.sort_index()
df2 = df2.set_index('Date')
df2 = df2.sort_index()
df1
# Out:
#                  Close  negative   neutral  positive        Open        High  \
# Date
# 2017-01-03   43.397999  0.050500  0.886250  0.063125   42.972000   44.066002
# 2017-01-04   45.397999  0.074762  0.850238  0.075048   42.950001   45.599998
# 2017-01-05   45.349998  0.000000  0.785000  0.215000   45.284000   45.495998
# 2017-01-06   45.801998       NaN       NaN       NaN   45.386002   46.062000
# 2017-01-09   46.256001       NaN       NaN       NaN   45.793999   46.383999
# ...                ...       ...       ...       ...         ...         ...
# 2022-05-02  902.940002       NaN       NaN       NaN  860.770020  906.359985
# 2022-05-03  909.250000       NaN       NaN       NaN  903.179993  924.080017
# 2022-05-04  952.619995       NaN       NaN       NaN  903.940002  955.500000
# 2022-05-05  873.280029  0.035167  0.883167  0.081667  939.020020  945.599976
# 2022-05-06  865.650024       NaN       NaN       NaN  887.000000  888.000000
#
#                    Low    Volume
# ...

# %%
df2
# Out:
#                  Close  negative   neutral  positive        Open        High  \
# Date
# 2017-01-03   43.397999  0.181000  0.763500  0.055500   42.972000   44.066002
# 2017-01-04   45.397999  0.009286  0.897286  0.093429   42.950001   45.599998
# 2017-01-05   45.349998  0.000000  0.898000  0.102000   45.284000   45.495998
# 2017-01-06   45.801998  0.072000  0.928000  0.000000   45.386002   46.062000
# 2017-01-09   46.256001  0.000000  0.815000  0.185000   45.793999   46.383999
# ...                ...       ...       ...       ...         ...         ...
# 2022-05-02  902.940002  0.045250  0.844950  0.109800  860.770020  906.359985
# 2022-05-03  909.250000  0.024722  0.908667  0.066611  903.179993  924.080017
# 2022-05-04  952.619995  0.044100  0.871200  0.084650  903.940002  955.500000
# 2022-05-05  873.280029  0.040071  0.894964  0.064929  939.020020  945.599976
# 2022-05-06  865.650024  0.017500  0.930214  0.052286  887.000000  888.000000
#
#                    Low    Volume
# ...

# %%
df3 = pd.concat((df1, df2))
df3 = df3.groupby(df3.index).mean()
df3
# Out:
#                  Close  negative   neutral  positive        Open        High  \
# Date
# 2017-01-03   43.397999  0.115750  0.824875  0.059312   42.972000   44.066002
# 2017-01-04   45.397999  0.042024  0.873762  0.084238   42.950001   45.599998
# 2017-01-05   45.349998  0.000000  0.841500  0.158500   45.284000   45.495998
# 2017-01-06   45.801998  0.072000  0.928000  0.000000   45.386002   46.062000
# 2017-01-09   46.256001  0.000000  0.815000  0.185000   45.793999   46.383999
# ...                ...       ...       ...       ...         ...         ...
# 2022-05-02  902.940002  0.045250  0.844950  0.109800  860.770020  906.359985
# 2022-05-03  909.250000  0.024722  0.908667  0.066611  903.179993  924.080017
# 2022-05-04  952.619995  0.044100  0.871200  0.084650  903.940002  955.500000
# 2022-05-05  873.280029  0.037619  0.889065  0.073298  939.020020  945.599976
# 2022-05-06  865.650024  0.017500  0.930214  0.052286  887.000000  888.000000
#
#                    Low      Volume
# ...

# %%
df3.to_csv('/content/drive/MyDrive/JU PROJ/Vader/Total_Tesla_stock_data.csv')
