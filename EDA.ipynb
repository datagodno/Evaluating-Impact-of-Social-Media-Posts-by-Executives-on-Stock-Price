# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %% [markdown]
# ### EDA seperate

# %% [markdown]
# #### REDDIT

# %% [markdown]
# General

# %%
stock_data = pd.read_csv('/content/drive/MyDrive/JU PROJ/Reddit/GENERAL_FINBERT_Reddit_data.csv', index_col = False)
stock_data.isnull().sum(axis = 0)
# Out:
# Date          0
# Close         0
# negative    854
# neutral     854
# positive    854
# Open          0
# High          0
# Low           0
# Volume        0
# dtype: int64

# %%
stock_data = stock_data.dropna()
stock_data.shape
# Out:
# (491, 9)

# %% [markdown]
# Executive

# %%
stock_data = pd.read_csv('/content/drive/MyDrive/JU PROJ/Reddit/Executive_FINBERT_Reddit_data.csv', index_col = False)
stock_data.isnull().sum(axis = 0)
# Out:
# Date          0
# Close         0
# negative    204
# neutral     204
# positive    204
# Open          0
# High          0
# Low           0
# Volume        0
# dtype: int64

# %%
stock_data = stock_data.dropna()
stock_data.shape
# Out:
# (1141, 9)

# %% [markdown]
# #### ETHEREUM

# %% [markdown]
# General

# %%
stock_data = pd.read_csv('/content/drive/MyDrive/JU PROJ/ETHEREUM/GENERAL_FINBERT_ETH_data.csv', index_col = False)
stock_data.isnull().sum(axis = 0)
# Out:
# Date        0
# Close       0
# negative    0
# neutral     0
# positive    0
# Open        0
# High        0
# Low         0
# Volume      0
# dtype: int64

# %%
stock_data = stock_data.dropna()
stock_data.shape
# Out:
# (1641, 9)

# %% [markdown]
# Executive

# %%
stock_data = pd.read_csv('/content/drive/MyDrive/JU PROJ/ETHEREUM/EXEC_FINBERT_ETH_data.csv', index_col = False)
stock_data.isnull().sum(axis = 0)
# Out:
# Date           0
# Close          0
# negative    1595
# neutral     1595
# positive    1595
# Open           0
# High           0
# Low            0
# Volume         0
# dtype: int64

# %%
stock_data = stock_data.dropna()
stock_data.shape
# Out:
# (46, 9)

# %% [markdown]
# #### BITCOIN

# %% [markdown]
# General

# %%
stock_data = pd.read_csv('/content/drive/MyDrive/JU PROJ/Bitcoin/GENERAL_FINBERT_BTC_data.csv', index_col = False)
stock_data.isnull().sum(axis = 0)
# Out:
# Date        0
# Close       0
# negative    0
# neutral     0
# positive    0
# Open        0
# High        0
# Low         0
# Volume      0
# dtype: int64

# %%
stock_data = stock_data.dropna()
stock_data.shape
# Out:
# (1952, 9)

# %% [markdown]
# Executive

# %%
stock_data = pd.read_csv('/content/drive/MyDrive/JU PROJ/Bitcoin/EXEC_FINBERT_BTC_data.csv', index_col = False)
stock_data.isnull().sum(axis = 0)
# Out:
# Date           0
# Close          0
# negative    1710
# neutral     1710
# positive    1710
# Open           0
# High           0
# Low            0
# Volume         0
# dtype: int64

# %%
stock_data = stock_data.dropna()
stock_data.shape
# Out:
# (242, 9)

# %% [markdown]
# #### AAPL

# %% [markdown]
# General

# %%
stock_data = pd.read_csv('/content/drive/MyDrive/JU PROJ/APPL/GENERAL_FINBERT_AAPL_data.csv', index_col = False)
stock_data.isnull().sum(axis = 0)
# Out:
# Date         0
# Close        0
# negative    24
# neutral     24
# positive    24
# Open         0
# High         0
# Low          0
# Volume       0
# dtype: int64

# %%
stock_data = stock_data.dropna()
stock_data.shape
# Out:
# (1334, 9)

# %% [markdown]
# Executive

# %%
stock_data = pd.read_csv('/content/drive/MyDrive/JU PROJ/APPL/EXEC_FINBERT_AAPL_data.csv', index_col = False)
stock_data.isnull().sum(axis = 0)
# Out:
# Date           0
# Close          0
# negative    1176
# neutral     1176
# positive    1176
# Open           0
# High           0
# Low            0
# Volume         0
# dtype: int64

# %%
stock_data = stock_data.dropna()
stock_data.shape
# Out:
# (182, 9)

# %% [markdown]
# #### TESLA

# %% [markdown]
# General

# %%
stock_data = pd.read_csv('/content/drive/MyDrive/JU PROJ/TSLA FinBERT/GENERAL_FINBERT_Tesla_stock_data.csv', index_col = False)
stock_data.isnull().sum(axis = 0)
# Out:
# Date        0
# Close       0
# negative    0
# neutral     0
# positive    0
# Open        0
# High        0
# Low         0
# Volume      0
# dtype: int64

# %%
stock_data = stock_data.dropna()
stock_data.shape
# Out:
# (1346, 9)

# %% [markdown]
# Executive

# %%
stock_data = pd.read_csv('/content/drive/MyDrive/JU PROJ/TSLA FinBERT/EXEC_FINBERT_Tesla_stock_data.csv', index_col = False)
stock_data.isnull().sum(axis = 0)
# Out:
# Date          0
# Close         0
# negative    577
# neutral     577
# positive    577
# Open          0
# High          0
# Low           0
# Volume        0
# dtype: int64

# %%
stock_data = stock_data.dropna()
stock_data.shape
# Out:
# (769, 9)
